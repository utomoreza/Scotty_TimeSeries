# %% [markdown]
# ## Load library yang perlu dan import data train

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm
from pylab import rcParams
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    rolmean = timeseries.rolling(window=12).mean()
    
    #Plot rolling statistics:
    fig, ax = plt.subplots(figsize = (17, 4))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Moving Average')
    plt.legend(loc='best')
    plt.title('Moving Average')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
scotty = pd.read_csv("data/data-train.csv")
#scotty.head()

scotty = scotty[['start_time','src_sub_area']]
#scotty.head()

scotty.info()

scotty.start_time = scotty.start_time.astype('datetime64[ns]')
scotty.columns = ['datetime','src_sub_area']
# print(scotty.head())
# print(scotty.tail())

scotty['datetime'] = scotty['datetime'].apply(lambda x: x.replace(minute=0, second=0))
# print(scotty.head())
# print(scotty.tail())

scotty_group = scotty.groupby(['datetime','src_sub_area']).count()
scotty_group.reset_index(inplace=True)

a = scotty.groupby(['datetime','src_sub_area'])['src_sub_area'].count()
scotty_group['demand'] = a.reset_index(drop=True)
# scotty_group.head()

scotty_group.sort_values(by=['src_sub_area','datetime'], inplace=True)

scotty_group = scotty_group.groupby('src_sub_area').\
    apply(lambda x : x.set_index('datetime').resample('H').sum().fillna(0)).\
    reset_index()

sxk97 = scotty_group[scotty_group.src_sub_area == 'sxk97']
sxk9e = scotty_group[scotty_group.src_sub_area == 'sxk9e']
sxk9s = scotty_group[scotty_group.src_sub_area == 'sxk9s']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90113 entries, 0 to 90112
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   start_time    90113 non-null  object
#  1   src_sub_area  90113 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB

# %%
sxk97 = sxk97.drop(columns=['src_sub_area'])
sxk97.set_index('datetime', inplace=True)

fig, ax = plt.subplots(figsize=(17,4))

plt.plot(sxk97)

plt.show()

# %%
sxk9e = sxk9e.drop(columns=['src_sub_area'])
sxk9e.set_index('datetime', inplace=True)

fig, ax = plt.subplots(figsize=(17,4))

plt.plot(sxk9e)

plt.show()

# %%
sxk9s = sxk9s.drop(columns=['src_sub_area'])
sxk9s.set_index('datetime', inplace=True)

fig, ax = plt.subplots(figsize=(17,4))

plt.plot(sxk9s)

plt.show()

# %%
rcParams['figure.figsize'] = 17, 8
decompose = sm.tsa.seasonal_decompose(sxk97, model='additive', period=24*7*4)
fig = decompose.plot()

sns 
plt.show()

# %%
pd.pivot_table(scotty_group, values='demand', index='datetime', columns=['src_sub_area'])
# Out:
# src_sub_area         sxk97  sxk9e  sxk9s
# datetime
# 2017-10-01 00:00:00      6      8     10
# 2017-10-01 01:00:00      4      2      3
# 2017-10-01 02:00:00      9      3      1
# 2017-10-01 03:00:00      2      2      0
# 2017-10-01 04:00:00      5      1      0
# ...                    ...    ...    ...
# 2017-12-02 19:00:00     56     84     54
# 2017-12-02 20:00:00     30     45     30
# 2017-12-02 21:00:00     59     57     38
# 2017-12-02 22:00:00     64     55     29
# 2017-12-02 23:00:00     57     26     41
#
# [1512 rows x 3 columns]

# %%
print(min(sxk97.index))
print(max(sxk97.index))
len(sxk97)
# Out:
# 2017-10-01 00:00:00
# 2017-12-02 23:00:00
# 1512

# %%
test_stationarity(sxk97)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -3.831016
# p-value                           0.002605
# #Lags Used                       24.000000
# Number of Observations Used    1487.000000
# Critical Value (1%)              -3.434755
# Critical Value (5%)              -2.863486
# Critical Value (10%)             -2.567806
# dtype: float64

# %%
def extractYMD(DT):
    print(str(DT.year) + '-' + str(DT.month) + '-' + str(DT.day))

from datetime import timedelta
interval = max_date - timedelta(days=6)

print('data validation used:')
print('from', end=' ')
print(calendar.day_name[interval.dayofweek], end=' ')
extractYMD(interval)
print('to', end=' ')
print(calendar.day_name[max_date.dayofweek], end=' ')
extractYMD(max_date)
# Out:
# data validation used:
# from Sunday 2017-11-26
# to Saturday 2017-12-2

# %%
import plotly.express as px

fig = px.line(sxk97, x='datetime', y='demand', width=950, height=300)
fig.show()
# Out:
# <div>
#
#
#             <div id="0356726b-f874-42c8-b54a-68678e07270d" class="plotly-graph-div" style="height:300px; width:950px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0356726b-f874-42c8-b54a-68678e07270d")) {
#                     Plotly.newPlot(
#                         '0356726b-f874-42c8-b54a-68678e07270d',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "datetime=%{x}<br>demand=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2017-10-01T00:00:00", "2017-10-01T01:00:00", "2017-10-01T02:00:00", "2017-10-01T03:00:00", "2017-10-01T04:00:00", "2017-10-01T05:00:00", "2017-10-01T06:00:00", "2017-10-01T07:00:00", "2017-10-01T08:00:00", "2017-10-01T09:00:00", "2017-10-01T10:00:00", "2017-10-01T11:00:00", "2017-10-01T12:00:00", "2017-10-01T13:00:00", "2017-10-01T14:00:00", "2017-10-01T15:00:00", "2017-10-01T16:00:00", "2017-10-01T17:00:00", "2017-10-01T18:00:00", "2017-10-01T19:00:00", "2017-10-01T20:00:00", "2017-10-01T21:00:00", "2017-10-01T22:00:00", "2017-10-01T23:00:00", "2017-10-02T00:00:00", "2017-10-02T01:00:00", "2017-10-02T02:00:00", "2017-10-02T03:00:00", "2017-10-02T04:00:00", "2017-10-02T05:00:00", "2017-10-02T06:00:00", "2017-10-02T07:00:00", "2017-10-02T08:00:00", "2017-10-02T09:00:00", "2017-10-02T10:00:00", "2017-10-02T11:00:00", "2017-10-02T12:00:00", "2017-10-02T13:00:00", "2017-10-02T14:00:00", "2017-10-02T15:00:00", "2017-10-02T16:00:00", "2017-10-02T17:00:00", "2017-10-02T18:00:00", "2017-10-02T19:00:00", "2017-10-02T20:00:00", "2017-10-02T21:00:00", "2017-10-02T22:00:00", "2017-10-02T23:00:00", "2017-10-03T00:00:00", "2017-10-03T01:00:00", "2017-10-03T02:00:00", "2017-10-03T03:00:00", "2017-10-03T04:00:00", "2017-10-03T05:00:00", "2017-10-03T06:00:00", "2017-10-03T07:00:00", "2017-10-03T08:00:00", "2017-10-03T09:00:00", "2017-10-03T10:00:00", "2017-10-03T11:00:00", "2017-10-03T12:00:00", "2017-10-03T13:00:00", "2017-10-03T14:00:00", "2017-10-03T15:00:00", "2017-10-03T16:00:00", "2017-10-03T17:00:00", "2017-10-03T18:00:00", "2017-10-03T19:00:00", "2017-10-03T20:00:00