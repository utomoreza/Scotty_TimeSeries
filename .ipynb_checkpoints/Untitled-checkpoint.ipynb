# %% [markdown]
# ## Load library yang perlu dan import data train

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
scotty = pd.read_csv("data/data-train.csv")
scotty.head()
# Out:
#                          id                   trip_id  \
# 0  59d005e1ffcfa261708ce9cd  59d005e9cb564761a8fe5d3e
# 1  59d0066affcfa261708ceb11                       NaN
# 2  59d006a1ffcfa261708ceba4  59d006c131e39c618969343d
# 3  59d006d8cb564761a8fe5efd  59d007193d32b861760d4a77
# 4  59d0073ecb564761a8fe5fdc                       NaN
#
#                   driver_id                  rider_id            start_time  \
# 0  59a892c5568be44b2734f276  59ad2d6efba75a581666b506  2017-10-01T00:00:17Z
# 1                       NaN  59cd704bcf482f6ce2fadfdb  2017-10-01T00:02:34Z
# 2  599dc0dfa5b4fd5471ad8453  59bd62cc7e3c3b663924ba86  2017-10-01T00:03:29Z
# 3  59a5856573d56e7103b5d51d  59c17cd1f6da2d274e16d0a7  2017-10-01T00:04:24Z
# 4                       NaN  596f47a8a294a82ea3e90e77  2017-10-01T00:06:06Z
#
#      src_lat    src_lon src_area src_sub_area   dest_lat   dest_lon dest_area  \
# 0  41.070468  29.019451     sxk9        sxk9s  41.117158  29.036495      sxk9
# 1  41.074868  28.995276     sxk9        sxk9e  41.083514  29.002277      sxk9
# 2  41.049952  29.031073     sxk9        sxk9s  41.044952  28.981922      sxk9
# 3  41.052873  28.995218     sxk9        sxk9e  41.081403  28.981973      sxk9
# 4  41.067595  28.988273     sxk9        sxk9e  41.021249  29.113156      sxk9
#
#   dest_sub_area   distance     status  confirmed_time_sec
# 0         sxk9u   5.379250  confirmed                   8
# 1         sxk9e   1.126098  nodrivers                   0
# 2         sxk9e   4.169492  confirmed                  32
# 3         sxk9e   3.358296  confirmed                  65
# 4         sxk9q  11.693573  nodrivers                   0

# %%
scotty = scotty[['start_time','src_sub_area']]
scotty.head()
# Out:
#              start_time src_sub_area
# 0  2017-10-01T00:00:17Z        sxk9s
# 1  2017-10-01T00:02:34Z        sxk9e
# 2  2017-10-01T00:03:29Z        sxk9s
# 3  2017-10-01T00:04:24Z        sxk9e
# 4  2017-10-01T00:06:06Z        sxk9e

# %%
scotty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90113 entries, 0 to 90112
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   start_time    90113 non-null  object
#  1   src_sub_area  90113 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB

# %%
scotty.start_time = scotty.start_time.astype('datetime64[ns]')
scotty.columns = ['datetime','src_sub_area']
print(scotty.head())
print(scotty.tail())
# Out:
#              datetime src_sub_area
# 0 2017-10-01 00:00:17        sxk9s
# 1 2017-10-01 00:02:34        sxk9e
# 2 2017-10-01 00:03:29        sxk9s
# 3 2017-10-01 00:04:24        sxk9e
# 4 2017-10-01 00:06:06        sxk9e
#                  datetime src_sub_area
# 90108 2017-12-02 23:57:45        sxk9s
# 90109 2017-12-02 23:58:52        sxk97
# 90110 2017-12-02 23:58:55        sxk9e
# 90111 2017-12-02 23:58:59        sxk9s
# 90112 2017-12-02 23:59:20        sxk9e

# %%
scotty['datetime'] = scotty['datetime'].apply(lambda x: x.replace(minute=0, second=0))
print(scotty.head())
print(scotty.tail())
# Out:
#     datetime src_sub_area
# 0 2017-10-01        sxk9s
# 1 2017-10-01        sxk9e
# 2 2017-10-01        sxk9s
# 3 2017-10-01        sxk9e
# 4 2017-10-01        sxk9e
#                  datetime src_sub_area
# 90108 2017-12-02 23:00:00        sxk9s
# 90109 2017-12-02 23:00:00        sxk97
# 90110 2017-12-02 23:00:00        sxk9e
# 90111 2017-12-02 23:00:00        sxk9s
# 90112 2017-12-02 23:00:00        sxk9e

# %%
scotty_group
# Out:
#                     src_sub_area  demand
# datetime
# 2017-10-01 00:00:00        sxk97       6
# 2017-10-01 01:00:00        sxk97       4
# 2017-10-01 02:00:00        sxk97       9
# 2017-10-01 03:00:00        sxk97       2
# 2017-10-01 04:00:00        sxk97       5
# ...                          ...     ...
# 2017-12-02 19:00:00        sxk9s      54
# 2017-12-02 20:00:00        sxk9s      30
# 2017-12-02 21:00:00        sxk9s      38
# 2017-12-02 22:00:00        sxk9s      29
# 2017-12-02 23:00:00        sxk9s      41
#
# [4225 rows x 2 columns]

# %%
scotty_group = scotty.groupby(['datetime','src_sub_area']).count()
scotty_group.reset_index(inplace=True)

# %%
a = scotty.groupby(['datetime','src_sub_area'])['src_sub_area'].count()
scotty_group['demand'] = a.reset_index(drop=True)
scotty_group.head()
# Out:
#              datetime src_sub_area  demand
# 0 2017-10-01 00:00:00        sxk97       6
# 1 2017-10-01 00:00:00        sxk9e       8
# 2 2017-10-01 00:00:00        sxk9s      10
# 3 2017-10-01 01:00:00        sxk97       4
# 4 2017-10-01 01:00:00        sxk9e       2

# %%
scotty_group.groupby('src_sub_area').apply(lambda x : x.set_index('datetime').resample('H').mean().fillna(0)).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-637a8027d3c5> in <module>
# ----> 1 scotty_group.groupby('src_sub_area').apply(lambda x : x.set_index('datetime').resample('H').mean().fillna(0)).reset_index()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     733         with option_context("mode.chained_assignment", None):
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#     737                 # gh-20949
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     749
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#     753         return self._wrap_applied_output(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     204             # group might be modified
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#     208                 mutated = True
#
# <ipython-input-132-637a8027d3c5> in <lambda>(x)
# ----> 1 scotty_group.groupby('src_sub_area').apply(lambda x : x.set_index('datetime').resample('H').mean().fillna(0)).reset_index()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['datetime'] are in the columns"

# %%
scotty_group.sort_values(by=['src_sub_area','datetime'], inplace=True)

# %%
min_datetime = min(scotty_group['datetime'])
max_datetime = max(scotty_group['datetime'])
idx = pd.date_range(min_datetime, max_datetime, freq='H')
idx = idx.append(idx).append(idx)

scotty_group.groupby('src_sub_area').apply(lambda x: x.set_index(idx).fillna(0)).reset_index()

#scotty_group.set_index('datetime', inplace=True)
#scotty_group.reindex(idx, fill_value=0)
#scotty_group.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-190ac867a02b> in <module>
#       5
#       6 scotty_group.set_index('datetime', inplace=True)
# ----> 7 scotty_group.reindex(idx, fill_value=0)
#       8 scotty_group.head(20)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     225         @wraps(func)
#     226         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 227             return func(*args, **kwargs)
#     228
#     229         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3854         kwargs.pop("axis", None)
#    3855         kwargs.pop("labels", None)
# -> 3856         return super().reindex(**kwargs)
#    3857
#    3858     def drop(
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4542         # perform the reindex on the axes
#    4543         return self._reindex_axes(
# -> 4544             axes, level, limit, tolerance, method, fill_value, copy
#    4545         ).__finalize__(self)
#    4546
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3742         if index is not None:
#    3743             frame = frame._reindex_index(
# -> 3744                 index, method, copy, level, fill_value, limit, tolerance
#    3745             )
#    3746
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3764             copy=copy,
#    3765             fill_value=fill_value,
# -> 3766             allow_dups=False,
#    3767         )
#    3768
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4611                 fill_value=fill_value,
#    4612                 allow_dups=allow_dups,
# -> 4613                 copy=copy,
#    4614             )
#    4615
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1249         # some axes don't allow reindexing with dups
#    1250         if not allow_dups:
# -> 1251             self.axes[axis]._can_reindex(indexer)
#    1252
#    1253         if axis >= self.ndim:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3096         # trying to reindex on an axis with duplicates
#    3097         if not self.is_unique and len(indexer):
# -> 3098             raise ValueError("cannot reindex from a duplicate axis")
#    3099
#    3100     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %%
min_datetime = min(scotty_group['datetime'])
max_datetime = max(scotty_group['datetime'])
idx = pd.date_range(min_datetime, max_datetime, freq='H')
scotty_group.set_index(idx)
#scotty_group.set_index('datetime')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-1b38d3648a4b> in <module>
#       2 max_datetime = max(scotty_group['datetime'])
#       3 idx = pd.date_range(min_datetime, max_datetime, freq='H')
# ----> 4 scotty_group.set_index(idx)
#       5 #scotty_group.set_index('datetime')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4345                 # ensure_index_from_sequences would not raise for append=False.
#    4346                 raise ValueError(
# -> 4347                     f"Length mismatch: Expected {len(self)} rows, "
#    4348                     f"received array of length {len(arrays[-1])}"
#    4349                 )
#
# ValueError: Length mismatch: Expected 4225 rows, received array of length 1512

# %%
- Lakukan time series padding agar data datetime terdaftar secara berurutan. Fungsi yang digunakan adalah `pad` dari library `padr

```{r}
min_date <- min(scotty$datetime) # tentukan datetime paling awal
max_date <- max(scotty$datetime) # tentukan datetime paling akhir

start_val <- make_datetime(year = year(min_date), month = month(min_date), day = day(min_date), hour = hour(min_date)) # buat dummy datetime berdasarkan min_date
end_val <- make_datetime(year = year(max_date), month = month(max_date), day = day(max_date), hour = hour(max_date)) # buat dummy datetime berdasarkan max_date

scotty_pad <- padr::pad(x = scotty, start_val = start_val, end_val = end_val)
```

- Setelah di-padding, akan didapatkan banyak data jam yang kosong pada kolom `demand` sehingga otomatis akan diisi dengan missing values. Ganti NA dengan nilai 0 karena walaupun NA, kita masih membutuhkan data tersebut, dan NA tersebut pada dasarnya mewakili ketiadaan order, alias 0 order.

```{r}
scotty_pad$demand <- replace_na(scotty_pad$demand, 0)
```

- Ubah dataframe menjadi objek timeseries dengan fungsi `ts` dan frequency di-set dengan nilai 24 karena kita ingin melihat seasonal harian dari data per jam.

```{r}
scotty_ts <- ts(scotty_pad$demand, frequency = 24)
head(scotty_ts)
```
